# %%
import pandas as pd

df = pd.read_parquet("../data/raw/merchants.parquet")

df.shape

df["segment"].value_counts()

df["state"].value_counts()
# Out:
# state
# SP    30578
# RJ    15549
# MG    15454
# PE     7717
# BA     7713
# DF     7712
# PR     7649
# RS     7628
# Name: count, dtype: int64
